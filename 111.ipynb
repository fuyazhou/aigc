# %%
# pip install pypdf chromadb tiktoken pandas scikit-learn panel docx2txt unstructured faiss-cpu

# %%
import os
import openai
import sys
from langchain.document_loaders import PyPDFLoader,PyPDFDirectoryLoader

# %%
openai.api_key = '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'
serper_key='034c5696b6b2b8322796f6a4de03af33b59f138c8252a57ff0f53aca06c41547'

# %%
from langchain.llms import OpenAI

llm = OpenAI(temperature=0, openai_api_key='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')

# %%
print(llm.predict("你好"))
# Out:
# 你好！

# %% [markdown]
# # load pdf

# %%
from langchain.document_loaders import PyPDFLoader
loader = PyPDFLoader("福田政务服务最新版(1)(1) (1).pdf")
pages = loader.load()

# %%
# loader = PyPDFLoader("福田产业高质量发展支持政策5.31 转曲-不可编辑 (1).pdf")
# pages = loader.load()

# %%
len(pages)
# Out:
# 45

# %%
page=pages[0]

# %%
page.page_content
# Out:
# '福田政务服务\n第一条福田办理法律援助\n1.办理对象\n自然人,事业法人,其他组织\n2.办理条件\n根据《广东省法律援助条例》的相关规定，经济困难公民、\n特殊案件当事人在遇到法律问题或者合法权益受到侵害时，\n可以申请法律援助。福利院、孤儿院、养老机构、光荣院、\n优抚医院、精神病院、SOS儿童村等社会福利机构，因维护\n其合法民事权益需要法律帮助的，法律援助机构根据其申请\n可以提供法律援助。社会组织依法对污染环境、破坏生态\n等损害社会公共利益的行为向人民法院提起民事公益诉讼\n的，法律援助机构根据其申请可以提供法律援助。无，查询\n人可窗口咨询，也可自行上网查询，也可以拨打法律援助机\n构的咨询电话查询或拨打12348查询。\n3.网上办理流程\n1.申请（1）申请人登录广东政务服务网，首次登陆需注册\n账号，选择相关业务，并提出网上预约申请，如需邮政快递\n送证服务，网上申请时，应按要求填写收件人相关信息。（2）\n网上预审（2个工作日，不包含在审批时限内），实施机关'

# %%
len(page.page_content)
# Out:
# 428

# %%
page.metadata
# Out:
# {'source': '福田政务服务最新版(1)(1) (1).pdf', 'page': 0}

# %% [markdown]
# # load url

# %%
from langchain.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://b19h258wz2a.feishu.cn/docx/SLeFdhCsfoyF8FxJfExczEL7nAh")
docs = loader.load()

# %%
print(docs[0].page_content[:500])
# Out:
# Docs        AI数据训练-需求文档Type "/" for commandsAI数据训练-需求文档​Feishu user 4713Created on July 5一、目前进展；​​1.产品形态；小程序、大屏、管理后台​小程序体验版入口；​​2.产品中主要模块；​（1）自由对话（问答直接对接chatGPT并且有联网能力）​（2）脑洞对话（基于AgentGPT的底层逻辑返回答案。注：提问后优先搜索本地训练的知识库返回，如搜索不到接着走GPT大模型）​（3）角色对话（返回答案只搜索本地知识库）​精准模式；一问一答搜索知识库​开放模式；将问题拆解最大上限10个后同步返回对应答案并返回后台设置的“关键词链接”/“关键词视频”​（4）工具（基于prompt问答）​​3.当前训练数据材料；​福田政务服务最新版(1)(1).pdf423.16KB福田产业高质量发展支持政策5.31 转曲-不可编辑.pdf120.40MB福保街道企业服务部实用手册2.0(1).docx577.82KB福i企问题场景(1).docx11.80KB数据来源；​（静态）​政府发布的政策文档内容​爬取政府官网政策

# %% [markdown]
# # load docx

# %%
from langchain.document_loaders import Docx2txtLoader
from langchain.document_loaders import UnstructuredWordDocumentLoader

# %%
loader = Docx2txtLoader("data/福保街道企业服务部实用手册2.0(1).docx")

# %%
data = loader.load()

# %%
data
# Out:
# [Document(page_content='福保街道企业服务实用手册\n\n（内部培训使用）\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\
n第一条  “福田英才荟”人才住房申请\t23\n\n第二条  福田区产业人才住房申请\t25\n\n（五）其他补贴\t31\n\n第一条 小微企业社保补贴\t31\n\n第二条 就业见习补贴\t33\n\n第二章  常办政务导航\t35\n\n一、个人政务\t35\n\n第一项 保障性住房（公租）轮候申请\t35\n\n第二项 保障性住房（安居）轮候申请\t38\n\n第三项 企业职工养老保险养老金申领\t41\n\n第四项 工伤认定申请\t43\n\n第五项 发放高龄老人补（津）贴\t44\n\n第六项 城镇独生子女父母计划生育奖励\t46\n\n第七项 往来港澳通行证自助签注\t49\n\n第八项 驾驶证期满换证\t49\n\n二、企业政务\t50\n\n第一项 房屋租赁登记备案\t50\n\n第二项 单位密码重置\t51\n\n第三项 产业资金申报\t52\n\n第三章  商事资源清单\t54\n\n第一项 法律业务服务\t54\n\n第二项 会计业务服务\t55\n\n第三项 金融业务服务\t56\n\n第四项 品牌IP策划服务\t56\n\
# ...

# %% [markdown]
# # data load summary

# %%
from langchain.vectorstores import FAISS

# %%
data_path="/home/ubuntu/gpt/data"

# %%
os.path.isfile(data_path)
# Out:
# False

# %%
os.path.isdir(data_path)
# Out:
# True

# %%
def load_data(data_path):
    """
    load data
    :return:
    """
    print("*******start load data*********")
    docs = []
    if os.path.isdir(data_path):
        for sub_data_path in os.listdir(data_path):
            if sub_data_path.endswith('.txt'):
                print(sub_data_path)
                loader = UnstructuredFileLoader(f'{data_path}/{sub_data_path}')
                doc = loader.load()
                
                all_page_text=[p.page_content for p in doc]
                joined_page_text="\n".join(all_page_text)
                docs.append(joined_page_text)

            if sub_data_path.endswith('.docx'):
                print(sub_data_path)
                loader = Docx2txtLoader(f'{data_path}/{sub_data_path}')
                doc = loader.load()
                                
                all_page_text=[p.page_content for p in doc]
                joined_page_text="\n".join(all_page_text)
                docs.append(joined_page_text)
                
                
            if sub_data_path.endswith('.pdf'):
                print(sub_data_path)
                loader = PyPDFLoader(f'{data_path}/{sub_data_path}')
                doc = loader.load()
                
                                
                all_page_text=[p.page_content for p in doc]
                joined_page_text="\n".join(all_page_text)
                docs.append(joined_page_text)
            
    if os.path.isfile(data_path):
        if data_path.endswith('.txt'):
            print(data_path)
            loader = UnstructuredFileLoader(data_path)
            doc = loader.load()

            all_page_text=[p.page_content for p in doc]
            joined_page_text="\n".join(all_page_text)
            docs.append(joined_page_text)

        if data_path.endswith('.docx'):
            print(data_path)
            loader = Docx2txtLoader(data_path)
            doc = loader.load()
            all_page_text=[p.page_content for p in doc]
            joined_page_text="\n".join(all_page_text)
            docs.append(joined_page_text)
        if data_path.endswith('.pdf'):
            print(data_path)
            loader = PyPDFLoader(data_path)
            doc = loader.load()
            all_page_text=[p.page_content for p in doc]
            joined_page_text="\n".join(all_page_text)
            docs.append(joined_page_text)
    print("*******load data done********")
    print(f"total have {len(docs)} datas")
    return docs

# %%
docs=load_data(data_path)
# Out:
# *******start load data*********
# 福田政务服务最新版(1)(1) (1).pdf
# 福i企问题场景(1).docx
# 福保街道企业服务部实用手册2.0(1).docx
# 福田产业高质量发展支持政策5.31 转曲-不可编辑 (1).pdf
# *******load data done********
# total have 4 datas

# %%
len(docs)
# Out:
# 4

# %%
text_splitter = CharacterTextSplitter(chunk_size=2000, chunk_overlap=500,separator="\n")
splits=[]
for doc in  docs:
    sub_splits=text_splitter.split_text(doc)
    splits.extend(sub_splits)

# %%
# 直接通过 txt  生成docus
documents = text_splitter.create_documents(docs)
len(documents)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[316], line 2
#       1 # 直接通过 txt  生成docus
# ----> 2 documents = text_splitter.create_documents(docs)
#       3 len(documents)
#
# File ~/anaconda3/envs/gpt/lib/python3.10/site-packages/langchain/text_splitter.py:99, in TextSplitter.create_documents(self, texts, metadatas)
#      97 for i, text in enumerate(texts):
#      98     index = -1
# ---> 99     for chunk in self.split_text(text):
#     100         metadata = copy.deepcopy(_metadatas[i])
#     101         if self._add_start_index:
#
# File ~/anaconda3/envs/gpt/lib/python3.10/site-packages/langchain/text_splitter.py:255, in CharacterTextSplitter.split_text(self, text)
#     253 """Split incoming text and return chunks."""
#     254 # First we naively split the large input into a bunch of smaller ones.
# ...

# %%
len(documents)
# Out:
# 37

# %%
len(docs)
# Out:
# 4

# %%
# Split
texts = text_splitter.split_text(docs[0])
text_splitter = RecursiveCharacterTextSplitter(chunk_size = 2000,
                                               chunk_overlap = 300,
                                               separators=["\n\n",  "(?<=\。 )", " ", "\n"])
for doc in docs:
    split = text_splitter.split_text(doc)
    break

# %% [markdown]
# # docu splitting

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter, CharacterTextSplitter

# %%
some_text = """When writing documents, writers will use document structure to group content. \
This can convey to the reader, which idea's are related. For example, closely related ideas \
are in sentances. Similar ideas are in paragraphs. Paragraphs form a document. \n\n  \
Paragraphs are often delimited with a carriage return or two carriage returns. \
Carriage returns are the "backslash n" you see embedded in this string. \
Sentences have a period at the end, but also, have a space.\
and words are separated by space."""

# %%
r_splitter = RecursiveCharacterTextSplitter(
    chunk_size=150,
    chunk_overlap=10,
    separators=["\n\n", "\n", "(?<=\. )", " ", ""]
)
r_splitter.split_text(some_text)
# Out:
# ["When writing documents, writers will use document structure to group content. This can convey to the reader, which idea's are related.",
#  'For example, closely related ideas are in sentances. Similar ideas are in paragraphs. Paragraphs form a document.',
#  'Paragraphs are often delimited with a carriage return or two carriage returns.',
#  'Carriage returns are the "backslash n" you see embedded in this string.',
#  'Sentences have a period at the end, but also, have a space.and words are separated by space.']

# %%
from langchain.document_loaders import PyPDFLoader,PyPDFDirectoryLoader
loader = PyPDFLoader("福田政务服务最新版(1)(1) (1).pdf")
pages = loader.load()

# %% [markdown]
# ## 把一个page变成一个文本txt

# %%
pages_list=["".join(page.page_content) for page in pages]
pages_txt="\n".join(pages_list)

# %%
data_path="福田政务服务最新版(1)(1) (1).pdf"
def get_off_data(data_path):
    loader = PyPDFLoader(data_path)
    pages = loader.load()
    pages_list=["".join(page.page_content) for page in pages]
    pages_txt="\n".join(pages_list)
    return pages,pages_txt

# %%
pages,pages_txt=get_off_data(data_path)

# %%
len(pages_txt)
# Out:
# 21920

# %%
from langchain.text_splitter import CharacterTextSplitter
text_splitter = CharacterTextSplitter(
    separator="\n",
    chunk_size=1000,
    chunk_overlap=150,
    length_function=len
)

# %%
r_text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=150,
    separators=["\n\n", "\n", "(?<=\。 )", " ", ""]
)

# %%
docs = text_splitter.split_documents(pages)

# %%
docs = r_text_splitter.split_documents(pages)

# %% [markdown]
# # Vectorstores and Embeddings
#
# Recall the overall workflow for retrieval augmented generation (RAG):

# %%
from langchain.document_loaders import PyPDFLoader

data_path="福田政务服务最新版(1)(1) (1).pdf"

# %%
# Load PDF
loaders = [
    # Duplicate documents on purpose - messy data
#     PyPDFLoader(data_path),
#     PyPDFLoader(data_path),
#     PyPDFLoader(data_path),
    PyPDFLoader(data_path)
]
docs = []
for loader in loaders:
    docs.extend(loader.load())

# %%
# Split
from langchain.text_splitter import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 1500,
    chunk_overlap = 150
)

# %%
splits = text_splitter.split_documents(docs)

# %%
from langchain.embeddings.openai import OpenAIEmbeddings
embedding = OpenAIEmbeddings(openai_api_key='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')

# %%
embedding
# Out:
# OpenAIEmbeddings(client=<class 'openai.api_resources.embedding.Embedding'>, model='text-embedding-ada-002', deployment='text-embedding-ada-002', openai_api_version='', openai_api_base='', openai_api_type='', openai_proxy='', embedding_ctx_length=8191, openai_api_key='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', openai_organization='', allowed_special=set(), disallowed_special='all', chunk_size=1000, max_retries=6, request_timeout=None, headers=None, tiktoken_model_name=None, show_progress_bar=False)

# %% [raw]
# MODEL                    NAME_TOKENIZER 	MAX INPUT TOKENS	OUTPUT DIMENSIONS
# text-embedding-ada-002	cl100k_base	        8191	               1536

# %%
sentence1 = "i like dogs"
sentence2 = "i like canines"
sentence3 = "the weather is ugly outside"

# %%
embedding1 = embedding.embed_query(sentence1)
embedding2 = embedding.embed_query(sentence2)
embedding3 = embedding.embed_query(sentence3)

# %%
len(embedding2)
# Out:
# 1536

# %%
from langchain.vectorstores import Chroma

# %%
persist_directory = 'docs/chroma/'

# %%
# !rm -rf ./docs/chroma  # remove old database files if any

# %%
vectordb = Chroma.from_documents(
    documents=documents,
    embedding=embedding,
    persist_directory=persist_directory
)

# %%
print(vectordb._collection.count())
# Out:
# 82

# %%
question = "申请残疾人就业补贴"

# %%
docs = vectordb.similarity_search(question,k=5)

# %%
len(docs)
# Out:
# 5

# %%
docs
# Out:
# [Document(page_content='3、补贴对象\n符合条件的人员。\n4、申请条件\n（一）劳动者属于就业困难人员。\n（二）以个人身份连续正常缴纳社会保险费满3个月以上的。\n（三）每周工作时间累计不低于20小时的，在以下灵活就业岗位工作：为他人（直系亲属除外）提供保姆、家政服务、病人看护、老人护理服务；从事餐饮服务；从事社区保洁、保绿工作；从事社区来料加工、工艺作坊、再生资源回收工作；依托互联网服务平台等新业态、新模式。\n5、申请时间\n灵活就业社会保险补贴采取先缴后补方式，就业困难人员每年申请一次补贴，对通过审核的，每3个月发放一次补贴。领取补贴满12个月仍然灵活就业的，应提前1个月提出继续补贴的申请。补缴社会保险费的月份不计发补贴。\n6、办理流程\n申请人可到户籍所在地或者经常居住地的街道公共就业服务机构提出补贴申请；也可在线上网上办理，登录“广东政务服务网”（https://www.gdzwfw.gov.cn/），搜索（深圳市）“灵活就业社保补贴申领”，点击“在线办理”，选择户籍地所在街道提出补贴申请。\n第三条 基层就业补贴\n1、补贴标准：3000元\n2、享受期限：一次性补贴\n3、补贴对象\n高校毕业生，包括普通高等学校的全日制本专科毕业生，以及全日制和非全日制硕士、博士毕业生。技工院校高级工班、预备技师班和特殊教育院校职业教育类毕业生，获得教育部留学服务中心学历学位认证的国（境）外高校毕业生，参照普通高等学校毕业生享受本清单有关扶持政策（以下简称申请人）。\n说明：机关事业单位编内人员除外;本项补贴与高校毕业生公共就业服务岗位补贴不得叠加享受。\n4、申请条件\n申请人符合以下条件之一的，可自愿申请一次性3000元的基层就业补贴：\n（一）在中小微企业就业的申请条件（同时满足以下条件)：\n1.申请人到本市登记注册且正常经营的中小微企业就业，与该企业签订了一年或以上期限劳动合同；\n2.在该企业连续正常缴交社会保险费满6个月；\n3.到企业就业时属于毕业2年内高校毕业生。\n说明：申请人就业单位属于深圳分公司且其总公司属于中小微企业的，可以申请补贴。\n（二）在个体工商户就业的申请条件（同时满足以下条件)：\n1.申请人（非个体工商户经营者本人）到本市登记注册且正常经营的个体工商户就业，与该个体工商户签订了一年或以上期限劳动
# ...

# %%
docs[0]==docs[1]
# Out:
# False

# %% [markdown]
# Let's save this so we can use it later!

# %%
vectordb.persist()

# %% [markdown]
# ## faiss
# https://python.langchain.com/docs/modules/data_connection/vectorstores/integrations/faiss

# %%
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import FAISS
from langchain.document_loaders import TextLoader

# %%
embedding = OpenAIEmbeddings()

# %%
db = FAISS.from_documents(documents, embedding)

# %%
query = "残疾人相关的政策"
docs = db.similarity_search(query)

# %%
for i in docs:
    print(i.page_content)
    print("\n\n")
# Out:
# 深圳市福田区政务服务中心综合窗口
# 2.深圳市福田区市花路1-8号河套深港科技创新合作区e站
# 通综合服务中心综合窗口
# 第四条申请残疾人就业补贴
# 1.办理对象
# 自然人
# 2.办理条件
# 1.在法定劳动年龄内（男性16-59岁，女性16-49岁，女干
# 部16-54岁）且持有深圳市残疾人联合会或福田区残疾人联
# 合会核发的《中华人民共和国残疾人证》的残疾人或在法定
# 劳动年龄内（男性16-59岁，女性16-49岁，女干部16-54
# 岁）且持有《中华人民共和国残疾军人证》的户籍残疾军人。
# 2.上岗就业已满一个月的；3.上岗前已进行失业登记，领取
# 了《深圳市残疾失业人员证》或《深圳市残疾失业员工证》；
# 4.已与用人单位签订一年以上劳动合同且在岗工作，并按规
# 定缴纳社会保险。 3.网上办理流程
# 1.申请人登录广东政务服务网
# (http://wsbs.sz.gov.cn/apply/ui/440304000000502677900000
# 0300175001)，提出申请，上传电子材料，预审通过后申请人
# 可以通过邮寄或亲自将材料送至福田区行政服务大厅残联
# 分厅。2.受理。福田区行政服务大厅残联分厅接收申请材料
# 即日作出受理或不予受理决定。符合申请条件，且材料齐全、
# 格式规范、符合法定形式的，予以受理，并以短信方式告知
# 受理结果；申请材料不齐全，退回材料告知补齐；格式不规
# 范、不符合法定形式的，不予受理。3.审核。即日内完成
# 审核。4.审批。审核结束即日做出审批决定。5.办结。即
# 日制作《深圳市残疾失业人员证》（未就业人员）或《深圳
# 市残疾失业员工证》（就业转失业人员），并加盖单位印章。
# 6.送达。申请人通过约定方式领取《深圳市残疾失业人员证》
# （未就业人员）或《深圳市残疾失业员工证》（就业转失业
籍残疾军人。\n2.上岗就业已满一个月的；3.上岗前已进行失业登记，领取\n了《深圳市残疾失业人员证》或《深圳市残疾失业员工证》；\n4.已与用人单位签订一年以上劳动合同且在岗工作，并按规\n定缴纳社会保险。 3.网上办理流程\n1.申请人登录广东政务服务网\n(http://wsbs.sz.gov.cn/apply/ui/440304000000502677900000\n0300175001)，提出申请，上传电子材料，预审通过后申请人\n可以通过邮寄或亲自将材料送至福田区行政服务大厅残联\n分厅。2.受理。福田区行政服务大厅残联分厅接收申请材料\n即日作出受理或不予受理决定。符合申请条件，且材料齐全、\n格式规范、符合法定形式的，予以受理，并以短信方式告知\n受理结果；申请材料不齐全，退回材料告知补齐；格式不规\n范、不符合法定形式的，不予受理。3.审核。即日内完成\n审核。4.审批。审核结束即日做出审批决定。5.办结。即\n日制作《深圳市残疾失业人员证》（未就业人员）或《深圳\n市残疾失业员工证》（就业转失业人员），并加盖单位印章。\n6.送达。申请人通过约定方式领取《深圳市残疾失业人员证》\n（未就业人员）或《深圳市残疾失业员工证》（就业转失业\n人员）（证件制作完成后，可至领取窗口领取或通过邮寄送\n达）。\n4.牵头部门\n深圳市福田区残疾人联合会\n5.办理地点\n深圳市福田区上梅林梅坳七路福康之家一楼3号窗口\n第五条申请残疾人失业登记 1.办理对象\n自然人\n2.办理条件\n在法定劳动年龄内（男性16-59岁，女性16-49岁，女干部\n16-54岁）且新申请办理《中华人民共和国残疾人证》的福\n田区未就业人员或就业转失
# ...

# %% [markdown]
# # Retrieval
#
# Retrieval is the centerpiece of our retrieval augmented generation (RAG) flow.
#
# Let's get our vectorDB from before.

# %%
from langchain.vectorstores import Chroma
from langchain.embeddings.openai import OpenAIEmbeddings
persist_directory = 'docs/chroma/'

# %%
os.environ['OPENAI_API_KEY']='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'

# %%
openai.api_key = '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'

# %%
embedding = OpenAIEmbeddings()
vectordb = Chroma(
    persist_directory=persist_directory,
    embedding_function=embedding
)

# %%
print(vectordb._collection.count())
# Out:
# 82

# %%
texts = [
    """The Amanita phalloides has a large and imposing epigeous (aboveground) fruiting body (basidiocarp).""",
    """A mushroom with a large fruiting body is the Amanita phalloides. Some varieties are all-white.""",
    """A. phalloides, a.k.a Death Cap, is one of the most poisonous of all known mushrooms.""",
]

# %%
smalldb = Chroma.from_texts(texts, embedding=embedding)

# %%
smalldb

# %%
question = "Tell me about all-white mushrooms with large fruiting bodies"

# %%
smalldb.similarity_search(question, k=2)
# Out:
# [Document(page_content='A mushroom with a large fruiting body is the Amanita phalloides. Some varieties are all-white.', metadata={}),
#  Document(page_content='The Amanita phalloides has a large and imposing epigeous (aboveground) fruiting body (basidiocarp).', metadata={})]

# %%
# 把相似程度高的去重
smalldb.max_marginal_relevance_search(question,k=2, fetch_k=3)
# Out:
# [Document(page_content='A mushroom with a large fruiting body is the Amanita phalloides. Some varieties are all-white.', metadata={}),
#  Document(page_content='A. phalloides, a.k.a Death Cap, is one of the most poisonous of all known mushrooms.', metadata={})]

# %% [markdown]
# ### Addressing Diversity: Maximum marginal relevance
#
# Last class we introduced one problem: how to enforce diversity in the search results.
#
# `Maximum marginal relevance` strives to achieve both relevance to the query *and diversity* among the results.

# %%
question = "人才补贴"
docs_ss = vectordb.similarity_search(question,k=3)

# %%
docs_ss
# Out:
# [Document(page_content='就业两年以上，所在机构应在福田区注册；2、已认定为深\n圳市高层次人才的包括杰出人才、国家级领军人才、地方级\n领军人才、后备级人才、海外高层次A类人才、海外高层次\nB类人才、海外高层次C类人才等市级人才层次，且人才证\n书在有效期内或到期不超过一年时间；3、已获得市级高层\n次人才奖励,且市发放高层次人才奖励拨款凭证时间为一年\n以内；4、申请人2021年9月1日前已领取过福田区高层\n次人才配套奖励，或未领取过福田区高层次人才配套奖励，\n但已在福田区备案；5、未享受过原福田英才荟政策新认定\n人才奖励；6、未享受过申请年份的福田区产业发展与创新\n人才奖配套奖励;7、申请年份未享受过《关于进一步实施福\n田英才荟计划的若干措施（2021）》中“2.2经营管理人才\n支持”所属奖励和4.4.1先进制造业经营管理人才奖励、4.4.2\n外贸及电商经营奖励，以及福田区产业资金个人奖励；8、\n该区级人才奖励不适用有高层次人才证书的国家公务员。\n三、申请人申请人才资质奖励支持需满足：取得正高职称，\n从事相应工作且在辖区同一家企业连续工作满3年的，奖励\n3万元；获得国家职业资格证书最高等级、职业技能等级证\n书最高等级，或取得注册会计师、执业药师、注册造价工程\n师等资格，且在辖区同一家企业职（执）业资格相应岗位连\n续工作满3年的，奖励2万元。申请条件如下：1、申请人\n所在的企业应在福田区注册及纳税。2、申请人应取得以下', metadata={'source': '福田政务服务最新版(1)(1) (1).pdf', 'page': 38}),
# ...

# %%
# 搜索指定的数据来源
docs = vectordb.similarity_search(
    question,
    k=3,
    filter={'source': '福田政务服务最新版(1)(1) (1).pdf'}
)

# %%
for d in docs:
    print(d.metadata)
# Out:
# {'source': '福田政务服务最新版(1)(1) (1).pdf', 'page': 38}
# {'source': '福田政务服务最新版(1)(1) (1).pdf', 'page': 40}
# {'source': '福田政务服务最新版(1)(1) (1).pdf', 'page': 11}

# %% [markdown]
# ### Addressing Specificity: working with metadata using self-query retriever
#
# But we have an interesting challenge: we often want to infer the metadata from the query itself.
#
# To address this, we can use `SelfQueryRetriever`, which uses an LLM to extract:
#
# 1. The `query` string to use for vector search
# 2. A metadata filter to pass in as well
#
# Most vector databases support metadata filters, so this doesn't require any new databases or indexes.

# %%
from langchain.llms import OpenAI
from langchain.retrievers.self_query.base import SelfQueryRetriever
from langchain.chains.query_constructor.base import AttributeInfo

# %%
metadata_field_info = [
    AttributeInfo(
        name="source",
        description="The lecture the chunk is from, should be one of `docs/cs229_lectures/MachineLearning-Lecture01.pdf`, `docs/cs229_lectures/MachineLearning-Lecture02.pdf`, or `docs/cs229_lectures/MachineLearning-Lecture03.pdf`",
        type="string",
    ),
    AttributeInfo(
        name="page",
        description="The page from the lecture",
        type="integer",
    ),
]

# %%
document_content_description = "Lecture notes"
llm = OpenAI(temperature=0)
retriever = SelfQueryRetriever.from_llm(
    llm,
    vectordb,
    document_content_description,
    metadata_field_info,
    verbose=True
)

# %%
all_file_list=[1,2,3]

# %%
for i in

# %% [markdown]
# # Additional tricks: compression
#
# Another approach for improving the quality of retrieved docs is compression.
#
# Information most relevant to a query may be buried in a document with a lot of irrelevant text.
#
# Passing that full document through your application can lead to more expensive LLM calls and poorer responses.
#
# Contextual compression is meant to fix this.

# %%
from langchain.retrievers import ContextualCompressionRetriever
from langchain.retrievers.document_compressors import LLMChainExtractor

# %%
def pretty_print_docs(docs):
    print(f"\n{'-' * 100}\n".join([f"Document {i+1}:\n\n" + d.page_content for i, d in enumerate(docs)]))

# %%
from langchain.chat_models import ChatOpenAI

# %%
# Wrap our vectorstore
# llm = OpenAI(temperature=0,)
llm = ChatOpenAI(temperature=0,model="gpt-3.5-turbo-16k")
compressor = LLMChainExtractor.from_llm(llm)

# %%
compression_retriever = ContextualCompressionRetriever(
    base_compressor=compressor,
    base_retriever=vectordb.as_retriever()
)

# %%
compression_retriever = ContextualCompressionRetriever(
    base_compressor=compressor,
    base_retriever=db.as_retriever()
)

# %%
question = "人才补贴"
compressed_docs = compression_retriever.get_relevant_documents(question)
pretty_print_docs(compressed_docs)
# Out:
# Document 1:
#
# 3、补贴对象
# 符合条件的人员。
# 4、申请条件
# （一）劳动者属于就业困难人员。
# （二）以个人身份连续正常缴纳社会保险费满3个月以上的。
# （三）每周工作时间累计不低于20小时的，在以下灵活就业岗位工作：为他人（直系亲属除外）提供保姆、家政服务、病人看护、老人护理服务；从事餐饮服务；从事社区保洁、保绿工作；从事社区来料加工、工艺作坊、再生资源回收工作；依托互联网服务平台等新业态、新模式。
# 5、申请时间
# 灵活就业社会保险补贴采取先缴后补方式，就业困难人员每年申请一次补贴，对通过审核的，每3个月发放一次补贴。领取补贴满12个月仍然灵活就业的，应提前1个月提出继续补贴的申请。补缴社会保险费的月份不计发补贴。
# 6、办理流程
# 申请人可到户籍所在地或者经常居住地的街道公共就业服务机构提出补贴申请；也可在线上网上办理，登录“广东政务服务网”（https://www.gdzwfw.gov.cn/），搜索（深圳市）“灵活就业社保补贴申领”，点击“在线办理”，选择户籍地所在街道提出补贴申请.
# ----------------------------------------------------------------------------------------------------
# Document 2:
#
# 第一条 吸纳脱贫人口就业补贴
# 1、补贴标准：5000元
# 2、享受期限：一次性
# 3、补贴对象
# 符合条件的用人单位（机关事业单位、劳务派遣单位除外）。
# 4、申请条件
# （一）用人单位招用本省以及对口协作地区（广西壮族自治区、贵州省、西藏自治区、新疆维吾尔自治区、云南省昭通市、重庆市巫山县、江西省寻乌县，对口协作地区另有调整的，从其规定）的脱贫人口，签订一年以上劳动合同。
# （二）用人单位为招用人员连续正常缴纳社会保险费6个月以上，且当前参保状态正常。
# （三）同一人员在同一单位就业的，本项补贴与其他吸纳就业补贴、创业带动就业补贴不得叠加享受。
# 6、申请时间
# 补贴对象应在满足连续正常缴纳社会保险费满6个月之日起1年内，向用人单位注册地所在街道公共就业服务机构提出补贴申请。
# 7、办理流程
# ...

# %%
compressed_docs[1]
# Out:
# Document(page_content='第一条 吸纳脱贫人口就业补贴\n1、补贴标准：5000元\n2、享受期限：一次性\n3、补贴对象\n符合条件的用人单位（机关事业单位、劳务派遣单位除外）。\n4、申请条件\n（一）用人单位招用本省以及对口协作地区（广西壮族自治区、贵州省、西藏自治区、新疆维吾尔自治区、云南省昭通市、重庆市巫山县、江西省寻乌县，对口协作地区另有调整的，从其规定）的脱贫人口，签订一年以上劳动合同。\n（二）用人单位为招用人员连续正常缴纳社会保险费6个月以上，且当前参保状态正常。\n（三）同一人员在同一单位就业的，本项补贴与其他吸纳就业补贴、创业带动就业补贴不得叠加享受。\n6、申请时间\n补贴对象应在满足连续正常缴纳社会保险费满6个月之日起1年内，向用人单位注册地所在街道公共就业服务机构提出补贴申请。\n7、办理流程\n吸纳脱贫人口的用人单位在社会统一用户平台（https://sipub.sz.gov.cn/suum/goLoginNew.do）注册账户（已注册账户用人单位无需再次注册），填写用人单位银行账户等相关信息。\n用人单位登录“深圳市脱贫人口劳务输出对接管理服务信息系统”（https://hrsspub.sz.gov.cn/szjzfpfw/login.jsp）录入脱贫人口基本信息，上传相应材料后提出申请。', metadata={})

# %%
compression_retriever = ContextualCompressionRetriever(
    base_compressor=compressor,
    base_retriever=vectordb.as_retriever(search_type = "mmr")
)

# %%
question = "人才补贴"
compressed_docs = compression_retriever.get_relevant_documents(question)
pretty_print_docs(compressed_docs)
# Out:
# /home/ubuntu/anaconda3/envs/gpt/lib/python3.10/site-packages/langchain/chains/llm.py:275: UserWarning: The predict_and_parse method is deprecated, instead pass an output parser directly to LLMChain.
#   warnings.warn(
# Document 1:
#
# 1、就业两年以上，所在机构应在福田区注册；2、已认定为深圳市高层次人才的包括杰出人才、国家级领军人才、地方级领军人才、后备级人才、海外高层次A类人才、海外高层次B类人才、海外高层次C类人才等市级人才层次，且人才证书在有效期内或到期不超过一年时间；3、已获
# ----------------------------------------------------------------------------------------------------
# Document 2:
#
# 2、申请人应当在辖区法人企业技能技术岗位连续工作1年以上且申请时在岗在职。3、同一人当年限申请一次奖励，获得更高荣誉或称号的给予补差奖励。获得更高荣誉或称号的时间应为当年度获得福田英才荟高技能人才奖励之后。4、同一人因同一技能限申请一项奖励。
# ----------------------------------------------------------------------------------------------------
# Document 3:
#
# 1、残疾人通过国家教育考试的在校就读的大专、本科、硕士及博士研究生。不予以批准的条件:已在其他部门申领学杂费补助的，不再享受前款规定的补助；2、残疾人通过国家认可的高等教育自学考试取得大专以上学历，可以凭毕业证书申请一次性补助4000元。不予以批准的条件已在其他部门申
# ----------------------------------------------------------------------------------------------------
# Document 4:
#
# ...

# %% [markdown]
# ## Other types of retrieval
#
# It's worth noting that vectordb as not the only kind of tool to retrieve documents.
#
# The `LangChain` retriever abstraction includes other ways to retrieve documents, such as TF-IDF or SVM.

# %%
from langchain.retrievers import SVMRetriever
from langchain.retrievers import TFIDFRetriever
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
data_path
# Out:
# '/home/ubuntu/gpt/data'

# %%
# Load PDF
loader = PyPDFLoader(data_path)
pages = loader.load()
all_page_text=[p.page_content for p in pages]
joined_page_text=" ".join(all_page_text)

# Split
text_splitter = RecursiveCharacterTextSplitter(chunk_size = 2000,
                                               chunk_overlap = 300,
                                               separators=["\n\n",  "(?<=\。 )", " ", "\n",""])
splits = text_splitter.split_text(joined_page_text)

# %%
len(joined_page_text)
# Out:
# 21920

# %%
print(splits[1])
# Out:
# 1.水土保持方案备案申请表（深圳）
# 2.生产建设项目水土保持方案报告书（表）（深圳市）
# 5.办理地点
# 1.深圳市福田区市花路1-8号河套深港科技创新合作区e站
# 通综合服务中心综合窗口
# 2.深圳市福田区国际创新中心F座3层（深南大道1006号）
# 深圳市福田区政务服务中心综合窗口
# 第三条办理预案备案
# 1.办理对象
# 企业法人
# 2.办理条件
# 1.重大危险源备案申请表；2.辨识、分级记录；3.重大危
# 险源基本特征表；4.涉及的所有化学品安全技术说明书；5.
# 区域位置图、平面布置图、工艺流程图和主要设备一览表；
# 6.重大危险源安全管理规章制度及安全操作规程（注：提供
# 清单）；7.安全监测监控系统、措施说明、检测、检验结果；
# 8.重大危险源事故应急预案、评审意见、演练计划和评估报
# 告；9.安全评估报告或者安全评价报告10.重大危险源关键
# 装置、重点部位的责任人、责任机构名称；11.重大危险源
# 场所安全警示标志的设置情况；12.其他文件、资料。11.
# 注册地或项目所在地为福田区深港科技创新合作区的企业 或个人，可通过信用承诺的方式申请。注册地或项目所在
# 地为福田区深港科技创新合作区的企业或个人，可通过信用
# 承诺的方式申请。1.重大危险源备案申请表；2.辨识、分级
# 记录；3.重大危险源基本特征表；4.涉及的所有化学品安
# 全技术说明书；5.区域位置图、平面布置图、工艺流程图和
# 主要设备一览表；6.重大危险源安全管理规章制度及安全操
# 作规程（注：提供清单）；7.安全监测监控系统、措施说明、
# 检测、检验结果；8.重大危险源事故应急预案、评审意见、
# 演练计划和评估报告；9.安全评估报告或者安全评价报告
# 10.重大危险源关键装置、重点部位的责任人、责任机构名称；
# 11.重大危险源场所安全警示标志的设置情况；12.其他文件、
# 资料。无受理条件。无受理条件。
# 3.网上办理流程
# 流程说明：收件-受理-审查-决定-制证-送达
# 4.申办材料
# 1.重大危险源特征表
# 2.重大危险源关键装置、重点部位的责任人、责任机构名称
# 3.区域位置图、平面布置图、工艺流程图和主要设备一览表
# 4.安全监测监控系统、措施说明、检测、检验结果
# ...

# %%
len(splits)
# Out:
# 37

# %%
# Retrieve
svm_retriever = SVMRetriever.from_texts(splits,embedding)
tfidf_retriever = TFIDFRetriever.from_texts(splits)

# %%
question = "残疾人补贴"
docs_svm=svm_retriever.get_relevant_documents(question)
# Out:
# /home/ubuntu/anaconda3/envs/gpt/lib/python3.10/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(

# %%
question = "残疾人"
docs_tfidf=tfidf_retriever.get_relevant_documents(question)

# %%
smalldb = Chroma.from_texts(splits, embedding=embedding)

# %%
mm=smalldb.similarity_search(query='残疾人技能奖励',k=3)

# %%
vectordb.similarity_search(query='残疾人技能奖励',k=3)
# Out:
# [Document(page_content='方式领取《中华人民共和国残疾人证》、《深圳市残疾失业\n人员证》（未就业人员）或《深圳市残疾失业员工证》（就\n业转失业人员）（证件制作完成后，可至领取窗口领取或通\n过邮寄送达）。\n4.牵头部门\n深圳市福田区残疾人联合会\n5.办理地点\n1.深圳市福田区福保街道福强路益田豪园居4栋4楼（福保\n社区工作站综合窗口）\n2.深圳市福田区上梅林梅坳七路福康之家一楼3号窗口\n3.深圳市福田区莲花街道红荔西路市政大院24栋首层（狮岭\n社区工作站综合窗口\n4.深圳市福田区福田街道福华路19号上武综合楼一楼（福华\n社区工作站综合窗口）\n5.深圳市福田区莲花街道雨田路莲花北村富莲三栋二楼东面\n（莲花北社区工作站综合窗口）等等\n第六条申请残疾人技能奖励\n1.办理对象\n自然人\n2.办理条件\n符合下列全部条件的，可提出申请：1.在法定劳动年龄内（男', metadata={'source': '福田政务服务最新版(1)(1) (1).pdf', 'page': 9}),
# ...

# %% [markdown]
# # Question Answering

# %%
import datetime
current_date = datetime.datetime.now().date()
if current_date < datetime.date(2023, 9, 2):
    llm_name = "gpt-3.5-turbo-0301"
else:
    llm_name = "gpt-3.5-turbo"
print(llm_name)
# Out:
# gpt-3.5-turbo-0301

# %%
llm_name = "gpt-3.5-turbo-16k"

# %%
from langchain.vectorstores import Chroma
from langchain.embeddings.openai import OpenAIEmbeddings
persist_directory = 'docs/chroma/'
embedding = OpenAIEmbeddings()
vectordb = Chroma(persist_directory=persist_directory, embedding_function=embedding)

# %%
print(vectordb._collection.count())
# Out:
# 45

# %%
question = "人才补贴"
docs = vectordb.similarity_search(question,k=3)
len(docs)
# Out:
# 3

# %%
from langchain.chat_models import ChatOpenAI
llm = ChatOpenAI(model_name=llm_name, temperature=0)

# %% [markdown]
# ### RetrievalQA chain

# %%
vectordb=smalldb

# %%
from langchain.chains import RetrievalQA

# %%
qa_chain = RetrievalQA.from_chain_type(
    llm,
    retriever=db.as_retriever()
)

# %%
question='残疾人'

# %%
result = qa_chain({"query": question})

# %%
result
# Out:
# {'query': '残疾人', 'result': '请问您有关残疾人的具体问题是什么？'}

# %% [markdown]
# ### Prompt

# %%
from langchain.prompts import PromptTemplate

# Build prompt
template = """Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer. Use three sentences maximum. Keep the answer as concise as possible. Always say "thanks for asking!" at the end of the answer. 
{context}
Question: {question}
Helpful Answer:"""



# Build prompt
template = """基于以下已知信息，回答用户的问题，尽量按照已知内容的原文回答。
                                            如果无法从中得到答案，请说 "根据已知信息无法回答该问题" 或 "没有提供足够的相关信息"，不允许在答案中添加编造成分，答案请使用中文。
                                            已知内容:
                                            {context}
                                            问题:
                                            {question}"""
QA_CHAIN_PROMPT = PromptTemplate.from_template(template)

# %%
template = """
                                            {context}
                                            \n\n
                                            
                                            根据上文请解释或者回答这个问题:
                                            {question}
                                            
                                            如果无法从中得到答案，请说 "根据已知信息无法回答该问题" 或 "没有提供足够的相关信息"，不允许在答案中添加编造成分，答案请使用中文。
                                            
                                            """
QA_CHAIN_PROMPT = PromptTemplate.from_template(template)

# %% [markdown]
# ## 官方的prompt
# https://platform.openai.com/docs/guides/gpt-best-practices/strategy-provide-reference-text

# %% [markdown]
# SYSTEM
# Use the provided articles delimited by triple quotes to answer questions. If the answer cannot be found in the articles, write "I could not find an answer."
#
# USER
# <insert articles, each delimited by triple quotes>
#
# Question: <insert question here>

# %%
print(template)
# Out:
#                                             {context}
#
#
#
#
#                                             根据上文请解释或者回答这个问题:
#                                             {question}
#
#                                             如果无法从中得到答案，请说 "根据已知信息无法回答该问题" 或 "没有提供足够的相关信息"，不允许在答案中添加编造成分，答案请使用中文。

# %%
# Run chain
qa_chain = RetrievalQA.from_chain_type(
    llm,
    retriever=vectordb.as_retriever(),
    return_source_documents=True,
    chain_type_kwargs={"prompt": QA_CHAIN_PROMPT}
)

# %%
result = qa_chain({"query": '福田区人才支持的办理条件'},)

# %%
result
# Out:
# {'query': '福田区人才支持的办理条件',
#  'result': '根据上文提供的信息，福田区人才支持的办理条件包括以下几个方面：\n\n1. 就业两年以上，所在机构应在福田区注册。\n2. 已认定为深圳市高层次人才，包括杰出人才、国家级领军人才、地方级领军人才、后备级人才、海外高层次A类人才、海外高层次B类人才、海外高层次C类人才等市级人才层次，且人才证书在有效期内或到期不超过一年时间。\n3. 已获得市级高层次人才奖励，并且市发放高层
source': '福田政务服务最新版(1)(1) (1).pdf', 'page': 38})

# %% [markdown]
# ### RetrievalQA chain types

# %%
qa_chain_mr = RetrievalQA.from_chain_type(
    llm,
    retriever=vectordb.as_retriever(),
    chain_type="map_reduce"
)

# %%
qa_chain_mr = RetrievalQA.from_chain_type(
    llm,
    retriever=vectordb.as_retriever(),
    chain_type="map_rerank"
)

# %%
result = qa_chain_mr({"query": question})

# %%
result
# Out:
# {'query': '申请福田区人才支持？',
#  'result': '根据提供的文本，无法确定是否有关于申请福田区人才支持的相关信息。请提供更多相关文本以便进行准确回答。'}

# %% [markdown]
# # chat

# %%
import panel as pn  # GUI
pn.extension()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='77ed3e7f-4b1e-4fb7-b690-89ee84cd505e'>
#   <div id="bb4faaf3-101b-4eef-875f-aaa2df5644f4" data-root-id="77ed3e7f-4b1e-4fb7-b690-89ee84cd505e" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
from langchain.vectorstores import Chroma
from langchain.embeddings.openai import OpenAIEmbeddings
persist_directory = 'docs/chroma/'
embedding = OpenAIEmbeddings()
vectordb = Chroma(persist_directory=persist_directory, embedding_function=embedding)

# %%
question = "人才补贴"
docs = vectordb.similarity_search(question,k=3)
len(docs)
# Out:
# 3

# %%
from langchain.chat_models import ChatOpenAI
llm = ChatOpenAI(model_name=llm_name, temperature=0)
llm.predict("Hello world!")
# Out:
# 'Hello! How can I assist you today?'

# %%
# Build prompt
from langchain.prompts import PromptTemplate
template = """Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer. Use three sentences maximum. Keep the answer as concise as possible. Always say "thanks for asking!" at the end of the answer. 
{context}
Question: {question}
Helpful Answer:"""
QA_CHAIN_PROMPT = PromptTemplate(input_variables=["context", "question"],template=template,)

# Run chain
from langchain.chains import RetrievalQA
# question = "Is probability a class topic?"
question = "如何办理人才补贴"

qa_chain = RetrievalQA.from_chain_type(llm,
                                       retriever=vectordb.as_retriever(),
                                       return_source_documents=True,
                                       chain_type_kwargs={"prompt": QA_CHAIN_PROMPT})


result = qa_chain({"query": question})
result["result"]
# Out:
# '申请人可以通过登录广东政务服务网提出申请，上传相关材料，并经过预审和受理的流程进行办理。具体的办理流程和要求可以在网上查询或咨询相关部门。 Thanks for asking!'

# %%
result
# Out:
# {'query': '如何办理人才补贴',
#  'result': '申请人可以通过登录广东政务服务网提出申请，上传相关材料，并经过预审和受理的流程进行办理。具体的办理流程和要求可以在网上查询或咨询相关部门。 Thanks for asking!',
#  'source_documents': [Document(page_content='5.办理地点\n深圳市福田区上梅林梅坳七路福康之家夹二层就业办公室\n第七条申请残疾人大学生学杂费补助\n1.办理对象\n自然人\n2.办理条件\n具有福田区户籍，年龄大于三周岁，符合残疾标准的视力、\n听力、言语、肢体、智力、精神及多重残疾人，满足下\n列条件之一的，予以批准：1、残疾人通过国家教育考试的\n在校就读的大专、本科、硕士及博士研究生。不予以批准\n的条件:已在其他部门申领学杂费补助的，不再享受前款规\n定的补助；2、残疾人通过国家认可的高等教育自学考试取\n得大专以上学历，可以凭毕业证书申请一次性补助4000元。\n不予以批准的条件已在其他部门申领学杂费补助的，不再\n享受前款规定的补助。\n3.网上办理流程\n申请人（或委托人）登陆“广东政务服务网”，提出申请，\n上传电子材料，预审通过后群众可以通过邮寄或亲自将材料\n送至社区公共服务站。2.受理：社区公共服务站接件人核验\n申请材料，申请人符合申请条件，材料齐全、格式规范、符\n合法定形式的，予以受理，当场出具《受理回执》；申请人', metadata={'source': '福田政务服务最新版(1)(1) (1).pdf', 'page': 11}),
# ...

# %% [markdown]
# # duckduckgo_search

# %%
from duckduckgo_search import ddg

# %%
results=ddg("今天是几号")

web_content = ''
if results:
    for result in results:
        web_content += result['body']+"\n\n"

